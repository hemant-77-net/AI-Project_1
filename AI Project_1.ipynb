# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'/content/drive/MyDrive/Data/diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
#train test split

# %%
predictors = df.drop("Outcome",axis=1)
Outcome = df["Outcome"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(predictors,Outcome,test_size=0.20,random_state=0 )

# %%
#Model fitting

# %%
from sklearn.linear_model import LogisticRegression
lr= LogisticRegression()
lr.fit(x_train,y_train)

y_pred_lr=lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
score_lr= round(accuracy_score(y_pred_lr,y_test)*100,2)

# %%
print("The accuracy score using Logisticregression is:"+str(score_lr)+"%")
# Out:
# The accuracy score using Logisticregression is:82.47%

# %%
#Neural Network

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model=Sequential()
model.add(Dense(11,activation="relu",input_dim=8))
model.add(Dense(1,activation="sigmoid"))

# %%
model.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 11)                99
#
#  dense_1 (Dense)             (None, 1)                 12
#
# ...
# Total params: 111 (444.00 Byte)
# Trainable params: 111 (444.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(x_train,y_train,epochs=200)
model.save_weights
# Out:
# Epoch 1/200
# 20/20 [==============================] - 3s 5ms/step - loss: 16.6293 - accuracy: 0.6042
# Epoch 2/200
# 20/20 [==============================] - 0s 3ms/step - loss: 12.2189 - accuracy: 0.5651
# Epoch 3/200
# 20/20 [==============================] - 0s 4ms/step - loss: 9.1338 - accuracy: 0.5277
# Epoch 4/200
# 20/20 [==============================] - 0s 4ms/step - loss: 6.9524 - accuracy: 0.4919
# Epoch 5/200
# 20/20 [==============================] - 0s 4ms/step - loss: 5.8332 - accuracy: 0.4821
# Epoch 6/200
# 20/20 [==============================] - 0s 4ms/step - loss: 5.0849 - accuracy: 0.4691
# Epoch 7/200
# 20/20 [==============================] - 0s 5ms/step - loss: 4.3585 - accuracy: 0.4577
# Epoch 8/200
# 20/20 [==============================] - 0s 4ms/step - loss: 3.6717 - accuracy: 0.4577
# Epoch 9/200
# 20/20 [==============================] - 0s 4ms/step - loss: 3.0417 - accuracy: 0.4984
# Epoch 10/200
# ...

# %%
y_pred_nn=model.predict(x_test)
# Out:
# 5/5 [==============================] - 0s 3ms/step

# %%
y_pred_nn.shape
# Out:
# (154, 1)

# %%
y_pred_nn
# Out:
# array([[0.8754566 ],
#        [0.13351788],
#        [0.18573289],
#        [0.57972574],
#        [0.27952617],
#        [0.0597663 ],
#        [0.5043666 ],
#        [0.5684319 ],
#        [0.46487865],
#        [0.6721022 ],
#        [0.28460595],
#        [0.8135098 ],
#        [0.27648807],
#        [0.4450525 ],
#        [0.04372563],
#        [0.21873267],
#        [0.74807566],
#        [0.13953693],
#        [0.25354543],
#        [0.32856497],
#        [0.43214536],
#        [0.3182005 ],
#        [0.33665073],
#        [0.06200076],
#        [0.19910713],
#        [0.42343798],
#        [0.11402987],
#        [0.5917861 ],
#        [0.21842194],
#        [0.30074608],
#        [0.3729388 ],
#        [0.16383335],
#        [0.15750885],
#        [0.82294154],
#        [0.3291215 ],
#        [0.65669954],
#        [0.36400422],
#        [0.06914766],
#        [0.639047  ],
#        [0.7749317 ],
#        [0.30148456],
#        [0.14474022],
#        [0.27632225],
# ...

# %%
rounded = [round(x[0]) for x in y_pred_nn]
y_pred_nn= rounded

# %%
score_nn=round(accuracy_score(y_pred_nn,y_test)*100,2)
print("The accuracy score using Neural network is: "+str(score_nn)+" %")
# Out:
# The accuracy score using Neural network is: 77.27 %
